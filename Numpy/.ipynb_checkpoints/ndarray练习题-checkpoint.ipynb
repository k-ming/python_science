# %%
'''
一周的天气为 [28,31,29,33,29.5,27,32.5]
求出最高温度
最低温度
平均温度
大于30度的天数
'''
import numpy as np

arr = np.array([28,31,29,33,29.5,27,32.5])
print('最高温度：', np.max(arr))
print('最低温度：', np.min(arr))
print('平均温度：', np.mean(arr))
print('大于30度的天数：', len(arr[arr > 30]))
# Out:
# 最高温度： 33.0
# 最低温度： 27.0
# 平均温度： 30.0
# 大于30度的天数： 3
